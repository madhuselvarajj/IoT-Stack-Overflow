# %%
#Code from Hesham: https://github.com/Hesham-E/IoT-Memory-Overflow/tree/main/CWE-120%20Buffer%20Copy%20without%20Checking%20Size%20of%20Input
#Text analysis of CWE 120 in C/C++ files generated from StackOverflow posts related to IoT

import os, re

# %%
functionsREGEX = ["(scanf[ ]*\([ ]*\"%s\")|(scanf\(.{1,}[,][ ]*\".*%s.*\")",
                  "(gets[ ]*\()", 
                  "(strcpy[ ]*\(.{1,}[,].{1,}\))", 
                  "(memcpy[ ]*\(.{1,}[,].{1,}\))", 
                  "(memmove[ ]*\(.{1,}[,].{1,}\))", 
                  "(memset[ ]*\(.{1,}[,].{1,}\))", 
                  "(strncat[ ]*\(.{1,}[,].{1,}[,].{1,}\))", 
                  "(strcat[ ]*\(.{1,}[,].{1,}\))", 
                  "(strncpy[ ]*\(.{1,}[,].{1,}[,].{1,}\))", 
                  "(sprintf|vsprintf|swprintf|vswprintf|_stprintf|_vstprintf)([ ]*\(.{1,}[,])",
                  "(MultiByteToWideChar[ ]*\(.{1,}[,].{1,}[,].{1,}[,].{1,}[,].{1,}[,].{1,}\))",
                  "(strtrns[ ]*\(.{1,}[,].{1,}[,].{1,}[,].{1,}\))", 
                  "(realpath[ ]*\(.{1,}[,].{1,}\))", 
                  "(getopt|getopt_long)([ ]*\(.{1,}[,].{1,}[,].{1,}\))", 
                  "(getwd[ ]*\(.{1,}[,].{1,}\))", 
                  "(getchar|fgetc|getc|read|_gettc)(\(.*\))"]

# %%
folderPath = './Testdata/'
fileList = os.listdir(folderPath)

# %%
def findFunctionCall (fileList, functionsKeywords):
    fileDict = dict()
    for fileName in fileList:
        print('Checking for \"CWE-120: Buffer Copy without Checking Size of Input\" in file ', fileName)
        print('-----------------------------------------------------------------------------\n')
        fileDict[fileName] = {"secure": True}
        fileR = open(folderPath + fileName, 'r')
        lines = fileR.readlines()
        vunerableCount = 0
        lineNum = 0

        for line in lines:
            lineNum += 1
            for functionREGEX in functionsREGEX:
                functionREGEX = '(?<!\/\/)' + functionREGEX #Expression to ensure that line is not a comment 
                lineNoWhiteSpace = "".join(line.split()) #Remove spaces since negative lookbehind pattern needs a definitive width
                match = re.search(functionREGEX, lineNoWhiteSpace)
                if match:
                    coord = match.span()
                    if coord[0] > line.find('//'): #Explicitly check that the match is before the comment
                        vunerableCount += 1
                        fileDict[fileName].update({"line" + str(lineNum): line.strip(), "secure": False})
                        print('Possible vulnerability : \"CWE-120: Buffer Copy without Checking Size of Input\"')
                        print('Need inspection at Line #',lineNum,' :',line.strip())
                        print()

        if vunerableCount == 0:
            print('No \"CWE-120: Buffer Copy without Checking Size of Input\" found in file: ',fileName)
        else:
            print(vunerableCount,'possible \"CWE-120: Buffer Copy without Checking Size of Input\" found in file: ',fileName)
        print('-----------------------------------------------------------------------------\n')
    return fileDict

# %%
findFunctionCall(fileList, functionsREGEX)
# Out:
# Checking for "CWE-120: Buffer Copy without Checking Size of Input" in file  post-1027458.cpp
# -----------------------------------------------------------------------------
#
# No "CWE-120: Buffer Copy without Checking Size of Input" found in file:  post-1027458.cpp
# -----------------------------------------------------------------------------
#
# Checking for "CWE-120: Buffer Copy without Checking Size of Input" in file  post-1027460-2.cpp
# -----------------------------------------------------------------------------
#
# Possible vulnerability : "CWE-120: Buffer Copy without Checking Size of Input"
# Need inspection at Line # 4  : memcpy(name_, name, min(16, strlen(name));
#
# 1 possible "CWE-120: Buffer Copy without Checking Size of Input" found in file:  post-1027460-2.cpp
# -----------------------------------------------------------------------------
#
# Checking for "CWE-120: Buffer Copy without Checking Size of Input" in file  post-1027460.cpp
# -----------------------------------------------------------------------------
#
# No "CWE-120: Buffer Copy without Checking Size of Input" found in file:  post-1027460.cpp
# -----------------------------------------------------------------------------
#
# Checking for "CWE-120: Buffer Copy without Checking Size of Input" in file  post-1027469.cpp
# -----------------------------------------------------------------------------
#
# No "CWE-120: Buffer Copy without Checking Size of Input" found in file:  post-1027469.cpp
# -----------------------------------------------------------------------------
#
# Checking for "CWE-120: Buffer Copy without Checking Size of Input" in file  post-1197139.cpp
# -----------------------------------------------------------------------------
#
# No "CWE-120: Buffer Copy without Checking Size of Input" found in file:  post-1197139.cpp
# -----------------------------------------------------------------------------
#
# Checking for "CWE-120: Buffer Copy without Checking Size of Input" in file  post-1197221-2.cpp
# -----------------------------------------------------------------------------
#
# No "CWE-120: Buffer Copy without Checking Size of Input" found in file:  post-1197221-2.cpp
# -----------------------------------------------------------------------------
#
# Checking for "CWE-120: Buffer Copy without Checking Size of Input" in file  post-1197221.cpp
# -----------------------------------------------------------------------------
#
# No "CWE-120: Buffer Copy without Checking Size of Input" found in file:  post-1197221.cpp
# -----------------------------------------------------------------------------
#
# Checking for "CWE-120: Buffer Copy without Checking Size of Input" in file  post-1198595.cpp
# -----------------------------------------------------------------------------
#
# No "CWE-120: Buffer Copy without Checking Size of Input" found in file:  post-1198595.cpp
# -----------------------------------------------------------------------------
#
# Checking for "CWE-120: Buffer Copy without Checking Size of Input" in file  post-1671941.c
# -----------------------------------------------------------------------------
#
# No "CWE-120: Buffer Copy without Checking Size of Input" found in file:  post-1671941.c
# -----------------------------------------------------------------------------
#
# Checking for "CWE-120: Buffer Copy without Checking Size of Input" in file  post-1787118.c
# -----------------------------------------------------------------------------
#
# No "CWE-120: Buffer Copy without Checking Size of Input" found in file:  post-1787118.c
# -----------------------------------------------------------------------------
#
# Checking for "CWE-120: Buffer Copy without Checking Size of Input" in file  post-1787123.c
# -----------------------------------------------------------------------------
#
# Possible vulnerability : "CWE-120: Buffer Copy without Checking Size of Input"
# Need inspection at Line # 6  : sprintf(strOut, "%02d", num);
#
# Possible vulnerability : "CWE-120: Buffer Copy without Checking Size of Input"
# Need inspection at Line # 8  : strcpy(strOut, "XX");
#
# 2 possible "CWE-120: Buffer Copy without Checking Size of Input" found in file:  post-1787123.c
# -----------------------------------------------------------------------------
#
# Checking for "CWE-120: Buffer Copy without Checking Size of Input" in file  post-1851406.cpp
# -----------------------------------------------------------------------------
#
# No "CWE-120: Buffer Copy without Checking Size of Input" found in file:  post-1851406.cpp
# -----------------------------------------------------------------------------
#
# Checking for "CWE-120: Buffer Copy without Checking Size of Input" in file  post-1851473.cpp
# -----------------------------------------------------------------------------
#
# Possible vulnerability : "CWE-120: Buffer Copy without Checking Size of Input"
# Need inspection at Line # 10  : sprintf( buf, "%0.1f", value );
#
# 1 possible "CWE-120: Buffer Copy without Checking Size of Input" found in file:  post-1851473.cpp
# -----------------------------------------------------------------------------
#
# Checking for "CWE-120: Buffer Copy without Checking Size of Input" in file  post-1851526.cpp
# -----------------------------------------------------------------------------
#
# No "CWE-120: Buffer Copy without Checking Size of Input" found in file:  post-1851526.cpp
# -----------------------------------------------------------------------------
#
# Checking for "CWE-120: Buffer Copy without Checking Size of Input" in file  post-824083.c
# -----------------------------------------------------------------------------
#
# Possible vulnerability : "CWE-120: Buffer Copy without Checking Size of Input"
# Need inspection at Line # 21  : sprintf(comDevice, "\\\\.\\COM%d", portIndex);
#
# 1 possible "CWE-120: Buffer Copy without Checking Size of Input" found in file:  post-824083.c
# -----------------------------------------------------------------------------
#
# Checking for "CWE-120: Buffer Copy without Checking Size of Input" in file  post-899226.c
# -----------------------------------------------------------------------------
#
# No "CWE-120: Buffer Copy without Checking Size of Input" found in file:  post-899226.c
# -----------------------------------------------------------------------------
#
# Checking for "CWE-120: Buffer Copy without Checking Size of Input" in file  post-949915-2.cpp
# -----------------------------------------------------------------------------
#
# No "CWE-120: Buffer Copy without Checking Size of Input" found in file:  post-949915-2.cpp
# -----------------------------------------------------------------------------
#
# Checking for "CWE-120: Buffer Copy without Checking Size of Input" in file  post-949915.cpp
# -----------------------------------------------------------------------------
#
# No "CWE-120: Buffer Copy without Checking Size of Input" found in file:  post-949915.cpp
# -----------------------------------------------------------------------------
#
# Checking for "CWE-120: Buffer Copy without Checking Size of Input" in file  post-949916.cpp
# -----------------------------------------------------------------------------
#
# No "CWE-120: Buffer Copy without Checking Size of Input" found in file:  post-949916.cpp
# -----------------------------------------------------------------------------
#
# Checking for "CWE-120: Buffer Copy without Checking Size of Input" in file  post-949981.cpp
# -----------------------------------------------------------------------------
#
# No "CWE-120: Buffer Copy without Checking Size of Input" found in file:  post-949981.cpp
# -----------------------------------------------------------------------------
#
# Checking for "CWE-120: Buffer Copy without Checking Size of Input" in file  post-950307.cpp
# -----------------------------------------------------------------------------
#
# No "CWE-120: Buffer Copy without Checking Size of Input" found in file:  post-950307.cpp
# -----------------------------------------------------------------------------
#
# Checking for "CWE-120: Buffer Copy without Checking Size of Input" in file  post-951046.cpp
# -----------------------------------------------------------------------------
#
# No "CWE-120: Buffer Copy without Checking Size of Input" found in file:  post-951046.cpp
# -----------------------------------------------------------------------------
#
# Checking for "CWE-120: Buffer Copy without Checking Size of Input" in file  post-982213.c
# -----------------------------------------------------------------------------
#
# No "CWE-120: Buffer Copy without Checking Size of Input" found in file:  post-982213.c
# -----------------------------------------------------------------------------
# {'post-1027458.cpp': {'secure': True},
#  'post-1027460-2.cpp': {'secure': False,
#   'line4': 'memcpy(name_, name, min(16, strlen(name));'},
#  'post-1027460.cpp': {'secure': True},
#  'post-1027469.cpp': {'secure': True},
#  'post-1197139.cpp': {'secure': True},
#  'post-1197221-2.cpp': {'secure': True},
#  'post-1197221.cpp': {'secure': True},
#  'post-1198595.cpp': {'secure': True},
#  'post-1671941.c': {'secure': True},
#  'post-1787118.c': {'secure': True},
#  'post-1787123.c': {'secure': False,
#   'line6': 'sprintf(strOut, "%02d", num);',
#   'line8': 'strcpy(strOut, "XX");'},
#  'post-1851406.cpp': {'secure': True},
#  'post-1851473.cpp': {'secure': False,
#   'line10': 'sprintf( buf, "%0.1f", value );'},
#  'post-1851526.cpp': {'secure': True},
#  'post-824083.c': {'secure': False,
#   'line21': 'sprintf(comDevice, "\\\\\\\\.\\\\COM%d", portIndex);'},
#  'post-899226.c': {'secure': True},
#  'post-949915-2.cpp': {'secure': True},
#  'post-949915.cpp': {'secure': True},
#  'post-949916.cpp': {'secure': True},
#  'post-949981.cpp': {'secure': True},
#  'post-950307.cpp': {'secure': True},
#  'post-951046.cpp': {'secure': True},
#  'post-982213.c': {'secure': True}}
